# %%
import MC_XY as mc
# %load_ext autoreload
# %autoreload 2

# %%
L = 32
T = [10**(-5), 0.5, 1.0, 1.4, 1.42, 1.45, 1.5, 2.0]
J = 1.0
rho = 1.0
size = 5

for temp in T:
    path = f"XY/J{J}/L{L}/T{temp:.3e}"
    mc.plot_results(path, L, temp, J, size=size)

path = f"XY/J{J}/L{L}"
mc.plot_chi_vs_T(path, L)
mc.plot_eta_vs_T(path, L)

# %%
path = f"XY/J{J}"
mc.plot_chi_vs_L(path, T)
mc.plot_chi_vs_T_all_L(path)
